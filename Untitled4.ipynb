# %%
print("family")
print("\tgrandfather")
print("\tgrandfather")
print("\t\tfather")
print("\t\tmother")
print("\t\t\tson")
print("\t\t\tdaughter")
# Out:
# family
# 	grandfather
# 	grandfather
# 		father
# 		mother
# 			son
# 			daughter

# %%
name1 = "family"
name2 = "grandfather"
name3 = "grandfather"
name4 = "father"
name5 = "mother"
name6 = "son"
name7 = "daughter"
tree = f"{name1.title()}\n\t{name2.title()}\n\t{name3.title()}\n\t\t{name4.title()}\n\t\t{name5.title()}\n\t\t\t{name6.title()}\n\t\t\t{name7.title()}"
print(tree)
# Out:
# Family
# 	Grandfather
# 	Grandfather
# 		Father
# 		Mother
# 			Son
# 			Daughter
